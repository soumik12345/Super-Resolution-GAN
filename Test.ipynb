# %%
from generator import *
from discriminator import *
from keras.utils.vis_utils import model_to_dot
from IPython.display import SVG
# Out:
# Using TensorFlow backend.

# %%
generator = Generator((384 // 4, 384 // 4, 3))
discriminator = Discriminator((384, 384, 3))
# Out:
# WARNING:tensorflow:From /home/soumikr/Workspace/SRGAN/env/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
generator.build_model()
discriminator.build_model()

# %%
SVG(
    model_to_dot(
        generator.model,
        show_shapes = True,
        show_layer_names = True
    ).create(
        prog = 'dot',
        format = 'svg'
    )
)

# %%
SVG(
    model_to_dot(
        discriminator.model,
        show_shapes = True,
        show_layer_names = True
    ).create(
        prog = 'dot',
        format = 'svg'
    )
)
